# %% [markdown]
# <a href="https://colab.research.google.com/github/aryagunjal04-dot/first-project/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number=int(input("ether any number:" ))
remainder=number%2
if remainder==0:
  print(f"{number} is even")
else:
  print(f"{number} is odd")
# Out:
# ether any number:5
# 5 is odd

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if (num1 >= num2) and (num1 >= num3):
   largest = num1
elif (num2 >= num1) and (num2 >= num3):
   largest = num2
else:
   largest = num3

print("The largest number is", largest)
# Out:
# Enter first number: 1
# Enter second number: 2
# Enter third number: 3
# The largest number is 3.0

# %%
num = int(input("Enter any number: "))

factorial = 1

if num < 0:
   print("Factorial does not exist for negative numbers")
elif num == 0:
   print("The factorial of 0 is 1")
else:
   for i in range(1, num + 1):
       factorial = factorial * i
   print("The factorial of", num, "is", factorial)
# Out:
# Enter any number: 5
# The factorial of 5 is 120

# %%
def count_vowels_consonants(text):
    """Counts the number of vowels and consonants in a given string."""
    text = text.lower()
    vowels = "aeiou"
    vowel_count = 0
    consonant_count = 0
    for char in text:
        if char.isalpha():
            if char in vowels:
                vowel_count += 1
            else:
                consonant_count += 1
    return vowel_count, consonant_count

input_string = input("Enter a string: ")
vowels, consonants = count_vowels_consonants(input_string)
print(f"Number of vowels: {vowels}")
print(f"Number of consonants: {consonants}")
# Out:
# Enter a string: aarya
# Number of vowels: 3
# Number of consonants: 2

# %%
num = int(input("Enter a number to generate its multiplication table: "))

print(f"Multiplication table for {num}:")
for i in range(1, 11):
   print(f"{num} x {i} = {num * i}")
# Out:
# Enter a number to generate its multiplication table: 5
# Multiplication table for 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
